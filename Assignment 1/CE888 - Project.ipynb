# %%
import pandas as pd

# %% [markdown]
# # 3-1) Load, clean, and explore the datasets provided (IHDP and JOBS), which are described in Section 4.
#
# ### Can you identify the causal questions for each dataset?

# %% [markdown]
# ## Loading the datasets

# %%
df_ihdp = pd.read_csv('D:/MSc Mudle/ce888/Project/Data/ihdp.txt', sep=',')
df_jobs = pd.read_csv('D:/MSc Mudle/ce888/Project/Data/jobs.txt', sep=',')

# %% [markdown]
# ## Cleaning & Exploring - JOBS & IHDP

# %%
df_jobs.describe().transpose()
# Out:
#       count          mean       std       min       25%       50%       75%  \
# x1   3212.0  2.427144e-16  1.000000 -1.461095 -0.802463 -0.332011  0.797073
# x2   3212.0 -3.843007e-16  1.000000 -3.986840 -0.579611  0.101835  0.442558
# x3   3212.0  3.742217e-01  0.483997  0.000000  0.000000  0.000000  1.000000
# x4   3212.0  4.887920e-02  0.215649  0.000000  0.000000  0.000000  0.000000
# x5   3212.0  7.079701e-01  0.454767  0.000000  0.000000  1.000000  1.000000
# x6   3212.0  4.118929e-01  0.492253  0.000000  0.000000  0.000000  1.000000
# x7   3212.0 -1.166909e-16  1.000000 -1.147411 -0.892339 -0.085212  0.550661
# x8   3212.0  1.195944e-17  1.000000 -1.110467 -0.913914 -0.083460  0.562908
# x9   3212.0  2.903448e-18  1.000000 -1.164047 -0.785284 -0.435556  0.673018
# x10  3212.0  1.759717e-14  1.000000 -0.948832 -0.743407 -0.499853  0.526738
# x11  3212.0 -2.706838e-16  1.000000 -2.143974 -0.670730 -0.022502  0.345809
# ...

# %%
df_ihdp.describe().transpose()
# Out:
#      count          mean       std       min       25%       50%       75%  \
# x1   747.0  5.528821e-17  1.000000 -2.731287 -0.666946  0.165275  0.813759
# x2   747.0  2.407713e-17  1.000000 -3.800823 -0.602710  0.196818  0.596582
# x3   747.0 -7.802772e-17  1.000000 -1.850350 -0.733261 -0.360898  0.756191
# x4   747.0 -9.060133e-16  1.000000 -0.879606 -0.879606  0.161703  0.161703
# x5   747.0  6.569191e-17  1.000000 -5.130428 -0.566672  0.121017  0.683672
# x6   747.0 -7.007261e-16  1.000000 -1.851480 -0.857787 -0.029709  0.632754
# x7   747.0  5.140562e-01  0.500137  0.000000  0.000000  1.000000  1.000000
# x8   747.0  9.370817e-02  0.291618  0.000000  0.000000  0.000000  0.000000
# x9   747.0  5.207497e-01  0.499904  0.000000  0.000000  1.000000  1.000000
# x10  747.0  3.641232e-01  0.481506  0.000000  0.000000  0.000000  1.000000
# x11  747.0  2.690763e-01  0.443777  0.000000  0.000000  0.000000  1.000000
# ...

# %%
df_jobs.isnull().sum()
# Out:
# x1     0
# x2     0
# x3     0
# x4     0
# x5     0
# x6     0
# x7     0
# x8     0
# x9     0
# x10    0
# x11    0
# x12    0
# x13    0
# x14    0
# x15    0
# x16    0
# x17    0
# t      0
# y      0
# e      0
# dtype: int64

# %%
df_ihdp.isnull().sum()
# Out:
# x1     0
# x2     0
# x3     0
# x4     0
# x5     0
# x6     0
# x7     0
# x8     0
# x9     0
# x10    0
# x11    0
# x12    0
# x13    0
# x14    0
# x15    0
# x16    0
# x17    0
# x18    0
# x19    0
# x20    0
# x21    0
# x22    0
# x23    0
# x24    0
# x25    0
# t      0
# yf     0
# ycf    0
# ite    0
# dtype: int64

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3212 entries, 0 to 3211
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      3212 non-null   float64
#  1   x2      3212 non-null   float64
#  2   x3      3212 non-null   float64
#  3   x4      3212 non-null   float64
#  4   x5      3212 non-null   float64
#  5   x6      3212 non-null   float64
#  6   x7      3212 non-null   float64
#  7   x8      3212 non-null   float64
#  8   x9      3212 non-null   float64
#  9   x10     3212 non-null   float64
#  10  x11     3212 non-null   float64
#  11  x12     3212 non-null   float64
#  12  x13     3212 non-null   float64
#  13  x14     3212 non-null   float64
#  14  x15     3212 non-null   float64
#  15  x16     3212 non-null   float64
#  16  x17     3212 non-null   float64
#  17  t       3212 non-null   float64
#  18  y       3212 non-null   float64
#  19  e       3212 non-null   float64
# dtypes: float64(20)
# ...

# %%
df_ihdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      747 non-null    float64
#  1   x2      747 non-null    float64
#  2   x3      747 non-null    float64
#  3   x4      747 non-null    float64
#  4   x5      747 non-null    float64
#  5   x6      747 non-null    float64
#  6   x7      747 non-null    float64
#  7   x8      747 non-null    float64
#  8   x9      747 non-null    float64
#  9   x10     747 non-null    float64
#  10  x11     747 non-null    float64
#  11  x12     747 non-null    float64
#  12  x13     747 non-null    float64
#  13  x14     747 non-null    float64
#  14  x15     747 non-null    float64
#  15  x16     747 non-null    float64
#  16  x17     747 non-null    float64
#  17  x18     747 non-null    float64
#  18  x19     747 non-null    float64
#  19  x20     747 non-null    float64
# ...

# %%
df_jobs.corr()[17:20]
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# t -0.237372 -0.143653  0.281734  0.067206 -0.378814  0.206721 -0.283930
# y -0.044480  0.107226 -0.111014  0.018436  0.132752 -0.130128  0.300295
# e -0.405787 -0.263105  0.474398  0.140814 -0.646513  0.402496 -0.476660
#
#          x8        x9       x10       x11       x12       x13       x14  \
# t -0.284214 -0.219096 -0.201880 -0.162170 -0.159697 -0.152971  0.232104
# y  0.325691 -0.054407 -0.062256  0.110381  0.157230  0.165043 -0.399577
# e -0.480361 -0.373804 -0.343844 -0.295217 -0.265437 -0.256895  0.408566
#
#         x15       x16       x17         t         y         e
# t  0.176294 -0.253152  0.028611  1.000000 -0.067504  0.592775
# y -0.423171  0.262530 -0.056662 -0.067504  1.000000 -0.183054
# e  0.335675 -0.427380  0.130264  0.592775 -0.183054  1.000000

# %%
df_ihdp.corr()[25:29]
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# t    0.100514  0.087451 -0.021431 -0.105434 -0.067987  0.101511  0.003759
# yf   0.053298  0.054696 -0.000115  0.115248 -0.091339  0.497450 -0.047416
# ycf -0.104293 -0.092696  0.042024  0.202556  0.027675  0.192973 -0.016101
# ite  0.016551  0.013747 -0.011086 -0.371473  0.083464 -0.793070  0.081029
#
#            x8        x9       x10  ...       x20       x21       x22  \
# t   -0.012104  0.148839 -0.075871  ... -0.098523  0.021096 -0.079773
# yf   0.027918  0.220441 -0.163734  ... -0.013108  0.057721 -0.108501
# ycf  0.023748 -0.051076  0.015796  ...  0.080557  0.003898  0.075102
# ite -0.050966 -0.195444  0.104622  ... -0.093906 -0.052748  0.071085
#
#           x23       x24       x25         t        yf       ycf       ite
# t   -0.108456 -0.101383  0.151313  1.000000  0.718338 -0.791515 -0.008942
# yf  -0.104460 -0.113997  0.122729  0.718338  1.000000 -0.429339 -0.508433
# ...

# %%
his=df_jobs.hist(bins=50, figsize=(20,15))

# %%
his=df_ihdp.hist(bins=50, figsize=(20,15))

# %%
# Imbalance Data
df_jobs['y'].value_counts(), df_jobs['t'].value_counts()
# Out:
# (1.0    2730
#  0.0     482
#  Name: y, dtype: int64,
#  0.0    2915
#  1.0     297
#  Name: t, dtype: int64)

# %%
imb_y = len(df_jobs[df_jobs.y==1])/len(df_jobs['y'])
imb_t = len(df_jobs[df_jobs.t==1])/len(df_jobs['t'])
imb_y, imb_t
# Out:
# (0.8499377334993773, 0.09246575342465753)

# %%
print('The percentage of the unemployed people that did not receive training is {}%, and'.format(round(len(df_jobs[(df_jobs.y==0)
                                                                    & (df_jobs.t==0)])/len(df_jobs[df_jobs.y==0]),4)*100))

print('the percentage of the trained people that are employed is {}%'.format(round(len(df_jobs[(df_jobs.y==1)
                                                                    & (df_jobs.t==1)])/len(df_jobs[df_jobs.t==1]),4)*100))
# Out:
# The percentage of the unemployed people that did not receive training is 86.1%, and
# the percentage of the trained people that are employed is 77.44%

# %% [markdown]
# # 3-2. Select appropriate evaluation metrics for each dataset. Justify your choices. Things to consider:
#
# ### Granularity of predictions and measured errors (average vs. individual).
# ### Whether the dataset includes counterfactual outcomes (or true individual effects).

# %% [markdown]
# df_jobs: Search for which metrics are suitable for imbalanced data (based on your lecture note probably: F1, precision, and recall are better for imbalanced)

# %% [markdown]
# # 3-3. Simple learners

# %% [markdown]
# ## (a) Choose at least one regression model that provides feature importances. Examples: linear regression, decision tree, random forest, boosted trees.

# %% [markdown]
# The general lidea is that random forest classifier is better for the classification problem and gradient boosting regression is better for continuous problem.
# But search it on the google and find the details why this is the case.
